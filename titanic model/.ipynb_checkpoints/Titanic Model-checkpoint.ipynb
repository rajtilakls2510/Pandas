# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
titanic=pd.read_csv('titanic_train.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.corr()['Survived']
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64

# %%
titanic.drop(columns=['Ticket','Cabin'],inplace=True)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Embarked
# 0      0   7.2500        S
# 1      0  71.2833        C
# 2      0   7.9250        S
# 3      0  53.1000        S
# 4      0   8.0500        S

# %%
titanic['Designation']=np.where(titanic['Name'].str.contains('Mr. '),'Mr',titanic['Name'])

# %%
titanic['Designation']=np.where(titanic['Name'].str.contains('Mrs. '),'Mrs',titanic['Designation'])

# %%
titanic['Designation']=np.where(titanic['Name'].str.contains('Miss. '),'Miss',titanic['Designation'])

# %%
titanic['Designation']=np.where(titanic['Name'].str.contains('Master. '),'Mas',titanic['Designation'])

# %% [markdown]
# Dropping only row with null Age and no designation

# %%
titanic.drop(766,axis='index',inplace=True)

# %%
mean_ages=titanic.groupby('Designation').mean()['Age'][['Mr','Mrs','Miss','Mas']]

# %%
mean_ages
# Out:
# Designation
# Mr      32.386250
# Mrs     35.898148
# Miss    21.773973
# Mas      4.574167
# Name: Age, dtype: float64

# %%
titanic[titanic['Age'].isna()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
x1=titanic[titanic['Designation']=='Mr']
x1.fillna(value={'Age': mean_ages['Mr']},inplace=True)
x1
# Out:
# C:\Users\The WonderlanD\Anaconda3\lib\site-packages\pandas\core\generic.py:6287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 12            13         0       3  Saundercock, Mr. William Henry  male
# ..           ...       ...     ...                             ...   ...
# 881          882         0       3              Markun, Mr. Johann  male
# ...

# %%
x2=titanic[titanic['Designation']=='Mrs']
x2.fillna(value={'Age': mean_ages['Mrs']},inplace=True)
x2
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 15            16         1       2
# ..           ...       ...     ...
# 871          872         1       1
# 874          875         1       2
# 879          880         1       1
# 880          881         1       2
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
x3=titanic[titanic['Designation']=='Miss']
x3.fillna(value={'Age': mean_ages['Miss']},inplace=True)
x3
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 2              3         1       3                    Heikkinen, Miss. Laina
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 11            12         1       1                  Bonnell, Miss. Elizabeth
# 14            15         0       3      Vestrom, Miss. Hulda Amanda Adolfina
# 22            23         1       3               McGowan, Miss. Anna "Annie"
# ..           ...       ...     ...                                       ...
# 866          867         1       2              Duran y More, Miss. Asuncion
# 875          876         1       3          Najib, Miss. Adele Kiamie "Jane"
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
x4=titanic[titanic['Designation']=='Mas']
x4.fillna(value={'Age': mean_ages['Mas']},inplace=True)
x4
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 16            17         0       3
# 50            51         0       3
# 59            60         0       3
# 63            64         0       3
# 65            66         1       3
# 78            79         1       2
# 125          126         1       3
# 159          160         0       3
# 164          165         0       3
# 165          166         1       3
# 171          172         0       3
# 176          177         0       3
# 182          183         0       3
# 183          184         1       2
# 193          194         1       2
# 261          262         1       3
# 278          279         0       3
# 305          306         1       1
# 340          341         1       2
# 348          349         1       3
# 386          387         0       3
# 407          408         1       2
# 445          446         1       1
# 480          481         0       3
# ...

# %%
titanic=x1.append([x2,x3,x4],ignore_index=True).sort_values('PassengerId')

# %%
titanic['Age'].isna().sum()
# Out:
# 0

# %%
titanic['Family']=titanic['SibSp']+titanic['Parch']
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 519            2         1       1
# 644            3         1       3
# 520            4         1       1
# 1              5         0       3
# ..           ...       ...     ...
# 643          886         0       3
# 824          888         1       1
# 825          889         0       3
# 517          890         1       1
# 518          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 519  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 644                             Heikkinen, Miss. Laina  female  26.000000
# 520       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 1                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
titanic['Embarked'].fillna(value='S',inplace=True)

# %%
titanic.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 519            2         1       1
# 644            3         1       3
# 520            4         1       1
# 1              5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 519  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 644                             Heikkinen, Miss. Laina  female  26.0      0
# 520       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 1                             Allen, Mr. William Henry    male  35.0      0
#
#      Parch     Fare Embarked Designation  Family
# 0        0   7.2500        S          Mr       1
# 519      0  71.2833        C         Mrs       1
# 644      0   7.9250        S        Miss       0
# 520      0  53.1000        S         Mrs       1
# ...

# %%
titanic.reset_index(inplace=True)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 866 entries, 0 to 865
# Data columns (total 13 columns):
# index          866 non-null int64
# PassengerId    866 non-null int64
# Survived       866 non-null int64
# Pclass         866 non-null int64
# Name           866 non-null object
# Sex            866 non-null object
# Age            866 non-null float64
# SibSp          866 non-null int64
# Parch          866 non-null int64
# Fare           866 non-null float64
# Embarked       866 non-null object
# Designation    866 non-null object
# Family         866 non-null int64
# dtypes: float64(2), int64(7), object(4)
# memory usage: 88.1+ KB

# %%
titanic.drop(columns=['index','PassengerId','Name','SibSp','Parch'],inplace=True)

# %%
titanic['Family']=np.where(titanic['Family']>3,4,titanic['Family'])

# %%
titanic['Family'].unique()
# Out:
# array([1, 0, 4, 2, 3], dtype=int64)

# %%
X=titanic.drop(columns=['Survived'])
X
# Out:
#      Pclass     Sex        Age     Fare Embarked Designation  Family
# 0         3    male  22.000000   7.2500        S          Mr       1
# 1         1  female  38.000000  71.2833        C         Mrs       1
# 2         3  female  26.000000   7.9250        S        Miss       0
# 3         1  female  35.000000  53.1000        S         Mrs       1
# 4         3    male  35.000000   8.0500        S          Mr       0
# ..      ...     ...        ...      ...      ...         ...     ...
# 861       3  female  39.000000  29.1250        Q         Mrs       4
# 862       1  female  19.000000  30.0000        S        Miss       0
# 863       3  female  21.773973  23.4500        S        Miss       3
# 864       1    male  26.000000  30.0000        C          Mr       0
# 865       3    male  32.000000   7.7500        Q          Mr       0
#
# [866 rows x 7 columns]

# %%
y=titanic['Survived']
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 861    0
# 862    1
# 863    0
# 864    1
# 865    0
# Name: Survived, Length: 866, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder(drop='first')

# %%
from sklearn.compose import make_column_transformer

# %%
column_trans=make_column_transformer(
                (ohe,['Sex','Embarked','Pclass','Family','Designation']),
                remainder='passthrough')

# %%
X=column_trans.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier=DecisionTreeClassifier(criterion='entropy',max_depth=3,splitter='random',max_leaf_nodes=4)

# %%
classifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=3, max_features=None, max_leaf_nodes=4,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random')

# %%
y_pred=classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.823076923076923

# %%
scores=[]
for i in range(1000):
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)
    classifier.fit(X_train,y_train)
    y_pred=classifier.predict(X_test)
    scores.append(accuracy_score(y_test,y_pred))
plt.plot(scores)
np.median(scores)
# Out:
# 0.8333333333333334

# %%
scores=[]
for i in range(1000):
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25)
    classifier.fit(X_train,y_train)
    y_pred=classifier.predict(X_test)
    scores.append(accuracy_score(y_test,y_pred))
plt.plot(scores)
np.median(scores)
# Out:
# 0.8341013824884793

# %%
scores=[]
for i in range(1000):
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15)
    classifier.fit(X_train,y_train)
    y_pred=classifier.predict(X_test)
    scores.append(accuracy_score(y_test,y_pred))
plt.plot(scores)
np.median(scores)
# Out:
# 0.8307692307692308

# %%
scores=[]
for i in range(1000):
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)
    classifier.fit(X_train,y_train)
    y_pred=classifier.predict(X_test)
    scores.append(accuracy_score(y_test,y_pred))
plt.plot(scores)
np.median(scores)
# Out:
# 0.8346153846153846

# %%
classifier.get_depth()
# Out:
# 3
